# %%
# Importing basic libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
plt.style.use('seaborn')

# %%
# Reading data from provided csv
df = pd.read_csv("../Downloads/Iris.csv")
print("Data imported successfully")
# Out:
# Data imported successfully

# %%
# Detect missing values.
df.isna().sum() 
# No Missing Values Found
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # K-Means Clustering

# %%
# Import required Libraries
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import numpy as np

# %%
x = df.iloc[:, [0, 1, 2, 3, 4]].values
x[:5]
# Out:
# array([[1. , 5.1, 3.5, 1.4, 0.2],
#        [2. , 4.9, 3. , 1.4, 0.2],
#        [3. , 4.7, 3.2, 1.3, 0.2],
#        [4. , 4.6, 3.1, 1.5, 0.2],
#        [5. , 5. , 3.6, 1.4, 0.2]])

# %%
cluster = KMeans(n_clusters = 3, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)

# %%
# Imort KElbowVisualizer for using “elbow” method to optimize number of clusters
from yellowbrick.cluster import KElbowVisualizer

# %%
elbow = KElbowVisualizer(cluster, k=(1,11))
elbow.fit(x);

# %%
#Using K-Means Clustering on the dataset
cluster = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
predict = cluster.fit_predict(x)

# %% [markdown]
# ### WITHOUT CENTROIDS

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(20,6))

ax1.scatter(x[predict == 0, 0], x[predicts == 0, 1], 
                s = 100, c = 'orange',marker= 'h', label = 'Iris - Setosa')
ax2.scatter(x[predict == 1, 0], x[predicts == 1, 1], 
            s = 100, c = 'green',marker= 'h', label = 'Iris - Versicolour')
ax3.scatter(x[predict == 2, 0], x[predicts == 2, 1],
            s = 100, c = 'blue',marker= 'h', label = 'Iris - Virginica')
ax1.legend()
ax2.legend()
ax3.legend()

# %% [markdown]
# ### WITH CENTROIDS

# %%
# Plotting the clusters 
plt.scatter(x[predict == 0, 0], x[predict == 0, 1], 
            s = 120, c = 'orange',marker= 'h', label = 'Iris - Setosa')
plt.scatter(x[predict == 2, 0], x[predict == 2, 1],
            s = 120, c = 'blue',marker= 'h', label = 'Iris - Virginica')
plt.scatter(x[predict == 1, 0], x[predict == 1, 1], 
            s = 120, c = 'green',marker= 'h', label = 'Iris - Versicolour')

# Plotting the centroids of the clusters
plt.scatter(cluster.cluster_centers_[:, 0], cluster.cluster_centers_[:,1], 
            s = 140, c = 'k',marker= 'h', label = 'Centroids')
plt.legend();
